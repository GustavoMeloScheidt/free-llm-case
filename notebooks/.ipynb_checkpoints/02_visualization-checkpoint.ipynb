# %% [markdown]
# # 📊 CSAT Clusters Visualization
# This notebook summarizes and visualizes the results of the TF-IDF + KMeans clustering and the LLM-generated summaries.
#
# **Goals:**
# 1. Analyze the distribution of CSAT scores.
# 2. Compare clusters by average CSAT and size.
# 3. Identify the *worst* clusters (lowest satisfaction).
# 4. Display the LLM summaries for quick interpretation.

# %% [markdown]
# ## Cell 1 — Title and Context

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import textwrap

sns.set(style="whitegrid", palette="muted")
plt.rcParams["figure.figsize"] = (10, 5)

# %% [markdown]
# ## Cell 2 — Imports

# %%
# Load the clustered data and LLM summaries
df = pd.read_csv("../data/csat_with_clusters.csv")
summ = pd.read_csv("../data/cluster_summaries.csv")

print(f"Rows: {len(df)}")
print(f"Clusters: {df['cluster'].nunique()}")

# Convert CSAT to numeric, just in case
df["csat"] = pd.to_numeric(df["csat"], errors="coerce")
# Out:
# Rows: 36161
# Clusters: 10

# %% [markdown]
# ## Cell 3 — Load data

# %%
# Load the clustered data and LLM summaries
df = pd.read_csv("../data/csat_with_clusters.csv")
summ = pd.read_csv("../data/cluster_summaries.csv")

print(f"Rows: {len(df)}")
print(f"Clusters: {df['cluster'].nunique()}")

# Convert CSAT to numeric, just in case
df["csat"] = pd.to_numeric(df["csat"], errors="coerce")
# Out:
# Rows: 36161
# Clusters: 10

# %% [markdown]
# ## Cell 4 — Basic CSAT Distribution

# %%
sns.countplot(x="csat", data=df)
plt.title("Distribution of CSAT scores")
plt.xlabel("CSAT")
plt.ylabel("Count")
plt.show()

print(df["csat"].describe())
# Out:
# count    36161.000000
# mean         4.086474
# std          1.506940
# min          1.000000
# 25%          4.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: csat, dtype: float64

# %% [markdown]
# ## Cell 5 — Mean CSAT per cluster

# %%
cluster_stats = df.groupby("cluster")["csat"].agg(["count", "mean"]).reset_index()
cluster_stats = cluster_stats.merge(
    summ[["cluster", "llm_summary"]], on="cluster", how="left"
)
cluster_stats = cluster_stats.sort_values("mean", ascending=False)
cluster_stats.head()
# Out:
#    cluster  count      mean                                        llm_summary
# 5        5    199  4.989950  **Titre :** Service Excellent\n\n**Idées princ...
# 0        0    688  4.968023  **Titre :** Service Client Exemplaire\n\n**Idé...
# 7        7    622  4.966238  **Titre :** Professionnalisme des conseillers\...
# 6        6    851  4.944771  **Titre :** Satisfaction totale\n\n**Idées pri...
# 8        8   4260  4.923944  ### Titre : Service Client Exemplaire\n\n### I...

# %% [markdown]
# ## Cell 6 — Bar plot of cluster averages

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="cluster", y="mean", data=cluster_stats, palette="coolwarm")
plt.title("Average CSAT per cluster")
plt.ylabel("Average CSAT")
plt.xlabel("Cluster")
plt.show()
# Out:
# /var/folders/hg/tdzk0jws7zs1gj02xfgx__f40000gn/T/ipykernel_36308/4193919108.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="cluster", y="mean", data=cluster_stats, palette="coolwarm")

# %% [markdown]
# ## Cell 7 — Cluster sizes

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="cluster", y="count", hue="cluster", data=cluster_stats, palette="Blues_d")
plt.title("Number of verbatims per cluster")
plt.ylabel("Count")
plt.xlabel("Cluster")
plt.show()
# Out:
# /var/folders/hg/tdzk0jws7zs1gj02xfgx__f40000gn/T/ipykernel_36308/23539486.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="cluster", y="count", data=cluster_stats, palette="Blues_d")

# %% [markdown]
# ## Cell 8 — Top negative clusters

# %%
low_csat = cluster_stats[cluster_stats["count"] >= 50].sort_values("mean").head(5)
low_csat[["cluster", "count", "mean", "llm_summary"]]
# Out:
#    cluster  count      mean                                        llm_summary
# 1        1  11469  3.075682  ### Titre : Communication Clientèle\n\n#### Ré...
# 3        3  15074  4.317965  **Titre court :** Qualité du service\n\n**Idée...
# 9        9    543  4.896869  **Titre :** Satisfaction Client Élevée\n\n**Id...
# 4        4   1297  4.909021  **Titre :** Satisfaction Client\n\n**Idées pri...
# 2        2   1158  4.919689  **Titre :** Service Efficace\n\n**Idées princi...

# %% [markdown]
# ## Cell 9 — Display readable summaries

# %%
for _, row in low_csat.iterrows():
    summary = textwrap.fill(str(row["llm_summary"]), width=120)
    print(f"\n{'='*80}")
    print(f"Cluster {int(row['cluster'])} | n={int(row['count'])} | CSAT mean={row['mean']:.2f}")
    print(summary)
# Out:
# ================================================================================
# Cluster 1 | n=11469 | CSAT mean=3.08
# ### Titre : Communication Clientèle  #### Résumé des idées principales : 1. **Manque de communication** : Les clients
# expriment un besoin accru d'informations claires et régulières, notamment concernant la sécurité et les procédures (ex.
# démarchage, activation de services). 2. **Qualité du service client** : Bien que certains conseillers soient appréciés
# pour leur écoute et leur aide, d'autres sont perçus comme agressifs ou peu attentifs, ce qui nuit à l'expérience client.
# 3. **Procédures complexes** : Les clients trouvent que les procédures sont trop compliquées et manquent de clarté, ce
# qui entraîne des frustrations et des déplacements inutiles.  #### Actions concrètes à entreprendre : 1. **Renforcer la
# communication** : Mettre en place une campagne d'information régulière par email pour tenir les clients informés des
# changements, des procédures et des questions de sécurité. 2. **Former le personnel** : Offrir des formations
# supplémentaires à tous les conseillers sur l'écoute active et la gestion des interactions avec les clients pour
# améliorer la qualité du service. 3. **Simplifier les procédures** : Réévaluer et simplifier les processus internes pour
# rendre les demandes et les activations de services plus fluides et compréhensibles pour les clients.
#
# ================================================================================
# Cluster 3 | n=15074 | CSAT mean=4.32
# **Titre court :** Qualité du service  **Idées principales :** 1. Les clients expriment des avis divergents sur la
# qualité du service, avec des retours positifs sur l'écoute et la réactivité de certains conseillers, mais aussi des
# critiques concernant des informations erronées et un service client parfois incompétent. 2. Les tarifs des forfaits sont
# jugés trop élevés par certains clients, ce qui pourrait affecter leur satisfaction globale. 3. Des demandes spécifiques,
# comme des remboursements ou des modifications d'abonnement, semblent parfois mal prises en charge, entraînant
# frustration chez les clients.  **Actions concrètes :** 1. Mettre en place un programme de formation continue pour les
# conseillers afin d'améliorer la qualité des informations fournies et l'écoute des clients. 2. Réévaluer la structure
# tarifaire des forfaits pour la rendre plus compétitive et attractive, notamment pour les associations sportives. 3.
# Créer un processus simplifié pour le traitement des demandes de remboursement et de modification d'abonnement, afin de
# garantir une réponse rapide et efficace aux clients.
#
# ================================================================================
# Cluster 9 | n=543 | CSAT mean=4.90
# **Titre :** Satisfaction Client Élevée  **Idées principales :** 1. Les clients expriment une satisfaction générale très
# positive. 2. La qualité du service est souvent mentionnée comme un point fort. 3. Les remerciements fréquents indiquent
# une expérience client réussie.  **Actions concrètes :** 1. Continuer à maintenir et à renforcer la qualité du service
# pour préserver cette satisfaction. 2. Mettre en place un programme de reconnaissance pour les employés qui excellent
# dans leur service client. 3. Collecter des retours plus détaillés pour identifier des axes d'amélioration et des
# opportunités de développement.
#
# ================================================================================
# Cluster 4 | n=1297 | CSAT mean=4.91
# **Titre :** Satisfaction Client  **Idées principales :** 1. Les clients expriment leur gratitude pour la réactivité et
# l’efficacité des conseillers et techniciens. 2. Le professionnalisme et la bonne humeur des employés sont souvent
# mentionnés, ce qui contribue à une expérience positive. 3. Les clients recommandent l'entreprise et envisagent de
# s'abonner grâce à la qualité du service reçu.  **Actions concrètes :** 1. Mettre en place un programme de reconnaissance
# pour les employés afin de valoriser leur professionnalisme et leur bonne humeur. 2. Organiser des sessions de formation
# régulières pour renforcer les compétences en service client et en communication des équipes. 3. Créer un système de
# feedback client pour recueillir des avis et suggestions, permettant d'améliorer continuellement le service.
#
# ================================================================================
# Cluster 2 | n=1158 | CSAT mean=4.92
# **Titre :** Service Efficace  **Idées principales :** 1. Les clients expriment une grande satisfaction concernant la
# rapidité et l'efficacité du service. 2. Le personnel, notamment Roxanne et Pierre Martin, est souvent mentionné pour sa
# clarté et son accueil. 3. Les clients sont prêts à recommander le service et à l'utiliser à nouveau, soulignant une
# expérience positive globale.  **Actions concrètes :** 1. Mettre en place un programme de reconnaissance pour les
# employés qui reçoivent des éloges, comme Roxanne et Pierre Martin, afin de maintenir la motivation et l'engagement du
# personnel. 2. Continuer à former le personnel sur l'importance de la communication claire et de la rapidité dans le
# service pour maintenir les standards élevés. 3. Créer un système de feedback régulier pour recueillir les avis des
# clients et identifier les domaines d'amélioration, tout en renforçant les points positifs déjà appréciés.

# %% [markdown]
# # Conclusions
#
# - The dataset shows a strong positive skew: most responses are 5⭐ (high satisfaction).
# - One or two clusters dominate in size — these correspond to *generic positive feedback*.
# - Clusters with lowest average CSAT reveal concrete issues:
#   - **Technician delays**
#   - **Network or fiber issues**
#   - **Billing/refund problems**
# - LLM summaries provide immediate business insights for each theme.
# - Future improvement: filter by low CSAT before clustering to better balance topics.
